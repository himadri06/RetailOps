# %% [markdown]
# BronzeWork Incremental
# Incremental Bronze Ingestion Logic with re-run safe watermark logic

# %% [markdown]
# STEP 1 --- Imports and Setup

# %%
import pyspark

# %%
from pyspark.sql import functions as F
from delta.tables import DeltaTable
from datetime import datetime
import uuid

# %% [markdown]
# env aware code

# %%
def get_spark():
    try:
        return spark  # Databricks
    except NameError:
        from pyspark.sql import SparkSession
        return SparkSession.builder.appName("RetailOps").getOrCreate()

spark = get_spark()#this code is better

# %%
spark.sql("use catalog reatilops")

# %%
spark.sql("create schema if not exists bronze_schema")
